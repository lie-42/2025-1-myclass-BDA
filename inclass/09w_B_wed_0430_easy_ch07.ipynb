# %% [markdown]
# <a href="https://colab.research.google.com/github/lie-42/2025-1-myclass-BDA/blob/main/inclass/09w_B_wed_0430_easy_ch07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #결측치 제거

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.dpi' : '100'})
# %config InlineBackend.figure_format = 'retina'

import pandas as pd
import numpy as np
df = pd.DataFrame({'sex'   : ['M', 'F', np.nan, 'M', 'F'],
                   'score' : [5, 4, 3, 4, None]})
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df.dropna()
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df.dropna(subset = ['score'])
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0

# %%
df_nomiss = df.dropna(subset = ['score'])
df_nomiss
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0

# %%
df_nomiss['score'] + 1
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# Name: score, dtype: float64

# %%
df.score.mean()
# Out:
# np.float64(4.0)

# %%
df['score'].sum()
# Out:
# np.float64(16.0)

# %%
df.groupby('sex').agg(mean_score = ('score', 'mean'),
                      sum_score  = ('score', 'sum'))
# Out:
#      mean_score  sum_score
# sex
# F           4.0        4.0
# M           4.5        9.0

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip'],
                   "born": [np.nan, pd.Timestamp("1940-04-25"), pd.NaT]})
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna()
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.dropna(axis=1)
# Out:
#        name
# 0    Alfred
# 1    Batman
# 2  Catwoman

# %%
df.isna()
# Out:
#     name    toy   born
# 0  False   True   True
# 1  False  False  False
# 2  False  False   True

# %%
df.dropna(axis='columns')
# Out:
#        name
# 0    Alfred
# 1    Batman
# 2  Catwoman

# %%
df.dropna(how='all')
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(how='any')
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.dropna(thresh=2)
# Out:
#        name        toy       born
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(thresh=1)
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(subset=['name', 'toy'])
# Out:
#        name        toy       born
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(subset=['toy'])
# Out:
#        name        toy       born
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(subset=['born'])
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %% [markdown]
# #빈 데이터프레임 확인 방법 df.empty

# %%
df1 = pd.DataFrame(index = ['row1', 'row2', 'row3'])
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: [row1, row2, row3]

# %%
df1.empty
# Out:
# True

# %%
df2 = pd.DataFrame(columns=['col1','col2','col3'])
df2
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3]
# Index: []

# %%
df2.empty
# Out:
# True

# %%
df3 = pd.DataFrame(index = ['row1', 'row2', 'row3'],
                   columns=['col1', 'col2', 'col3'])
df3
# Out:
#      col1 col2 col3
# row1  NaN  NaN  NaN
# row2  NaN  NaN  NaN
# row3  NaN  NaN  NaN

# %%
df3.empty
# Out:
# False

# %%
df4 = pd.DataFrame(np.nan,
                  index = ['row1', 'row2', 'row3'],
                  columns=['col1','col2','col3'])
df4
# Out:
#       col1  col2  col3
# row1   NaN   NaN   NaN
# row2   NaN   NaN   NaN
# row3   NaN   NaN   NaN

# %%
df4.empty
# Out:
# False

# %%
df5 = pd.DataFrame(2,
                  index = ['row1', 'row2', 'row3'],
                  columns=['col1','col2','col3'])
df5
# Out:
#       col1  col2  col3
# row1     2     2     2
# row2     2     2     2
# row3     2     2     2

# %%
df5.empty
# Out:
# False

# %% [markdown]
# #결측값 대체

# %%
# !git clone https://github.com/ai7dnn/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 2.14 MiB | 6.01 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
exam = pd.read_csv('data/exam.csv')
exam.loc[[2, 7, 14], ['math']] = np.nan
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1  50.0       98       50
# 1    2       1  60.0       97       60
# 2    3       1   NaN       86       78
# 3    4       1  30.0       98       58
# 4    5       2  25.0       80       65
# 5    6       2  50.0       89       98
# 6    7       2  80.0       90       45
# 7    8       2   NaN       78       25
# 8    9       3  20.0       98       15
# 9   10       3  50.0       98       45
# 10  11       3  65.0       65       65
# 11  12       3  45.0       85       32
# 12  13       4  46.0       98       65
# 13  14       4  48.0       87       12
# 14  15       4   NaN       56       78
# 15  16       4  58.0       98       65
# 16  17       5  65.0       68       98
# 17  18       5  80.0       78       90
# 18  19       5  89.0       68       87
# 19  20       5  78.0       83       58

# %%
exam.loc[[2, 7, 14], ['math']]
# Out:
#     math
# 2    NaN
# 7    NaN
# 14   NaN

# %%
type(exam.loc[[2, 7, 14], ['math']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(
exam.loc[[2, 7, 14], 'math'])
# Out:
# pandas.core.series.Series

# %%
exam.loc[[2,7,14],'math']
# Out:
# 2    NaN
# 7    NaN
# 14   NaN
# Name: math, dtype: float64

# %%
exam.loc[[2,7,14]]
# Out:
#     id  nclass  math  english  science
# 2    3       1   NaN       86       78
# 7    8       2   NaN       78       25
# 14  15       4   NaN       56       78

# %% [markdown]
# #결측값 채워넣기 fillna()

# %%
exam['math'] = exam['math'].fillna(0)
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1  50.0       98       50
# 1    2       1  60.0       97       60
# 2    3       1   0.0       86       78
# 3    4       1  30.0       98       58
# 4    5       2  25.0       80       65
# 5    6       2  50.0       89       98
# 6    7       2  80.0       90       45
# 7    8       2   0.0       78       25
# 8    9       3  20.0       98       15
# 9   10       3  50.0       98       45
# 10  11       3  65.0       65       65
# 11  12       3  45.0       85       32
# 12  13       4  46.0       98       65
# 13  14       4  48.0       87       12
# 14  15       4   0.0       56       78
# 15  16       4  58.0       98       65
# 16  17       5  65.0       68       98
# 17  18       5  80.0       78       90
# 18  19       5  89.0       68       87
# 19  20       5  78.0       83       58

# %%
exam.loc[[2,7,14]]
# Out:
#     id  nclass  math  english  science
# 2    3       1   0.0       86       78
# 7    8       2   0.0       78       25
# 14  15       4   0.0       56       78

# %%
exam.loc[[2, 7, 14], ['math']] = np.nan
exam.loc[[2, 7, 14]]
# Out:
#     id  nclass  math  english  science
# 2    3       1   NaN       86       78
# 7    8       2   NaN       78       25
# 14  15       4   NaN       56       78

# %%
exam['math']=exam['math'].fillna(exam['math'].mean())
exam
# Out:
#     id  nclass       math  english  science
# 0    1       1  50.000000       98       50
# 1    2       1  60.000000       97       60
# 2    3       1  55.235294       86       78
# 3    4       1  30.000000       98       58
# 4    5       2  25.000000       80       65
# 5    6       2  50.000000       89       98
# 6    7       2  80.000000       90       45
# 7    8       2  55.235294       78       25
# 8    9       3  20.000000       98       15
# 9   10       3  50.000000       98       45
# 10  11       3  65.000000       65       65
# 11  12       3  45.000000       85       32
# 12  13       4  46.000000       98       65
# 13  14       4  48.000000       87       12
# 14  15       4  55.235294       56       78
# 15  16       4  58.000000       98       65
# 16  17       5  65.000000       68       98
# 17  18       5  80.000000       78       90
# 18  19       5  89.000000       68       87
# 19  20       5  78.000000       83       58

# %%
pd.set_option('display.precision', 2)
exam.loc[[2,7,14]]
# Out:
#     id  nclass   math  english  science
# 2    3       1  55.24       86       78
# 7    8       2  55.24       78       25
# 14  15       4  55.24       56       78

# %%
exam.math.isna().sum()
# Out:
# np.int64(0)

# %%
df = pd.DataFrame({'sex'   : [1, 2, 1, 3, 2, 1],
                   'score' : [5, 4, 3, 4, 2, 6]})
df
# Out:
#    sex  score
# 0    1      5
# 1    2      4
# 2    1      3
# 3    3      4
# 4    2      2
# 5    1      6

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    3
# 2    2
# 3    1
# Name: count, dtype: int64

# %%
df['sex'].value_counts().sort_index()
# Out:
# sex
# 1    3
# 2    2
# 3    1
# Name: count, dtype: int64

# %%
df['sex'].value_counts().sort_values()
# Out:
# sex
# 3    1
# 2    2
# 1    3
# Name: count, dtype: int64

# %%
df['score'].value_counts()
# Out:
# score
# 4    2
# 5    1
# 3    1
# 2    1
# 6    1
# Name: count, dtype: int64

# %%
df['score'].value_counts().sort_index()
# Out:
# score
# 2    1
# 3    1
# 4    2
# 5    1
# 6    1
# Name: count, dtype: int64

# %%
df
# Out:
#    sex  score
# 0    1      5
# 1    2      4
# 2    1      3
# 3    3      4
# 4    2      2
# 5    1      6

# %%
df['sex'] = np.where(df['sex'] == 3, np.nan, df['sex'])
df
# Out:
#    sex  score
# 0  1.0      5
# 1  2.0      4
# 2  1.0      3
# 3  NaN      4
# 4  2.0      2
# 5  1.0      6

# %%
df['score'] = np.where(df['score'] > 5 , np.nan, df['score'])
df
# Out:
#    sex  score
# 0  1.0    5.0
# 1  2.0    4.0
# 2  1.0    3.0
# 3  NaN    4.0
# 4  2.0    2.0
# 5  1.0    NaN

# %%
df.dropna(subset = ['sex', 'score']).groupby('sex').agg(mean_score = ('score', 'mean'))
# Out:
#      mean_score
# sex
# 1          4.67
# 2          3.00
# 3          4.00

# %%
df = pd.DataFrame([1])
df
# Out:
#    0
# 0  1

# %%
df = pd.DataFrame([1, 1, 2, 2])
df
# Out:
#    0
# 0  1
# 1  1
# 2  2
# 3  2

# %%
df = pd.DataFrame([[1, 1, 2, 2]])
df
# Out:
#    0  1  2  3
# 0  1  1  2  2

# %%
df = pd.DataFrame({'x1' : [1, 1, 2, 2]})
df['x2'] = np.where(df['x1'] == 1, 10, np.nan)  # 조건에 맞으면 문자 부여
df
# Out:
#    x1    x2
# 0   1  10.0
# 1   1  10.0
# 2   2   NaN
# 3   2   NaN

# %%
df.isna()
# Out:
#       x1     x2
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False   True

# %%
df = pd.DataFrame({'x1' : [1, 1, 2, 2]})
df['x2'] = np.where(df['x1'] == 1, 'a', None)
df
# Out:
#    x1    x2
# 0   1     a
# 1   1     a
# 2   2  None
# 3   2  None

# %%
df.isna()
# Out:
#       x1     x2
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      4 non-null      int64
#  1   x2      2 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes

# %%
df = pd.DataFrame({'x1' : [1, 1, 2, 2]})
df['x2'] = np.where(df['x1'] == 1, 'a', 'etc')
df
# Out:
#    x1   x2
# 0   1    a
# 1   1    a
# 2   2  etc
# 3   2  etc

# %%
df['x2'] = df['x2'].replace('etc', np.nan)
df
# Out:
#    x1   x2
# 0   1    a
# 1   1    a
# 2   2  NaN
# 3   2  NaN

# %%
df.isna()
# Out:
#       x1     x2
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False   True

# %%
df = df.fillna(10)
df
# Out:
#    x1  x2
# 0   1   a
# 1   1   a
# 2   2  10
# 3   2  10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      4 non-null      int64
#  1   x2      4 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes

# %%
type(df.loc[2,'x2'])
# Out:
# int

# %% [markdown]
# #이상값 알아보기 outlier

# %%
mpg = pd.read_csv('data/mpg.csv')
mpg.sample(5)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 73         dodge  ram 1500 pickup 4wd    5.9  1999    8    auto(l4)   4   11
# 38         dodge          caravan 2wd    3.0  1999    6    auto(l4)   f   17
# 107        honda                civic    2.0  2008    4  manual(m6)   f   21
# 219   volkswagen                jetta    2.8  1999    6    auto(l4)   f   16
# 18     chevrolet   c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
#
#      hwy fl    category
# 73    15  r      pickup
# 38    24  r     minivan
# 107   29  p  subcompact
# 219   23  r     compact
# 18    20  r         suv

# %%
mpg.describe()
# Out:
#         displ     year     cyl     cty     hwy
# count  234.00   234.00  234.00  234.00  234.00
# mean     3.47  2003.50    5.89   16.86   23.44
# std      1.29     4.51    1.61    4.26    5.95
# min      1.60  1999.00    4.00    9.00   12.00
# 25%      2.40  1999.00    4.00   14.00   18.00
# 50%      3.30  2003.50    6.00   17.00   24.00
# 75%      4.60  2008.00    8.00   19.00   27.00
# max      7.00  2008.00    8.00   35.00   44.00

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
mpg.hwy.describe()
# Out:
# count    234.00
# mean      23.44
# std        5.95
# min       12.00
# 25%       18.00
# 50%       24.00
# 75%       27.00
# max       44.00
# Name: hwy, dtype: float64

# %%
import seaborn as sns
sns.boxplot(data=mpg, y='hwy')

#맨위는 이상값
#iqr 25~75퍼센트 - 박스의 높이, 길이 // 박스 길이의 1.5배 를 벗어나면 아웃 라이어/ 위,아래
#정상범위에서의 가장큰값, 정상범위에서의 가장 작은값 iqr

#박스플롯의 구성요소
# Out:
# <Axes: ylabel='hwy'>

# %%
s = pd.Series([1, 2, 3, 4, 5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s.quantile([.1, .25, .50, .75, 1])
# Out:
# 0.10    1.4
# 0.25    2.0
# 0.50    3.0
# 0.75    4.0
# 1.00    5.0
# dtype: float64

# %%
s.quantile()
##미디안값 . 정중앙에 있는값
# Out:
# np.float64(3.0)

# %%
s.quantile(.5)
# Out:
# np.float64(3.0)

# %%
mpg.hwy.describe()
# Out:
# count    234.00
# mean      23.44
# std        5.95
# min       12.00
# 25%       18.00
# 50%       24.00
# 75%       27.00
# max       44.00
# Name: hwy, dtype: float64

# %%
mpg.hwy.quantile([.1, .25, .50, .75, 1])
# Out:
# 0.10    16.3
# 0.25    18.0
# 0.50    24.0
# 0.75    27.0
# 1.00    44.0
# Name: hwy, dtype: float64

# %%
a,b=[10,20]
a

b
# Out:
# 20

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
pct25, pct50, pct75 = mpg['hwy'].quantile([.25, .5, .75])
pct25
# Out:
# 18.0

# %%
pct50
# Out:
# 24.0

# %%
iqr = pct75 - pct25
iqr
# Out:
# 9.0

# %%
## upper fence
upper_fence = pct75 + 1.5 * iqr
upper_fence
# Out:
# 40.5

# %%
## lower fence
lower_fence = pct25 - 1.5 * iqr
lower_fence
# Out:
# 4.5

# %%
mpg['hwy'].describe()
# Out:
# count    234.00
# mean      23.44
# std        5.95
# min       12.00
# 25%       18.00
# 50%       24.00
# 75%       27.00
# max       44.00
# Name: hwy, dtype: float64

# %%
mpg['hwy'].describe()['25%']
# Out:
# np.float64(18.0)

# %%
mpg['hwy'].describe()['max']
# Out:
# np.float64(44.0)

# %%
mpg[mpg.hwy > upper_fence]
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#        category
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
mpg[mpg.hwy < lower_fence]
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, cty, hwy, fl, category]
# Index: []

# %%
mpg.isna().sum()
# Out:
# manufacturer    0
# model           0
# displ           0
# year            0
# cyl             0
# trans           0
# drv             0
# cty             0
# hwy             0
# fl              0
# category        0
# dtype: int64

# %%
mpg[(mpg.hwy > upper_fence) | (mpg.hwy < lower_fence)]
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#        category
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
mpg['hwy'] = np.where((mpg['hwy'] < lower_fence) | (mpg['hwy'] > upper_fence), np.nan, mpg['hwy'])

# %%
mpg['hwy'].isna().sum()
# Out:
# np.int64(3)

# %%
mpg[ mpg.hwy.isna()]
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33  NaN  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35  NaN  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29  NaN  d
#
#        category
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
dmpg = mpg.dropna(subset = ['hwy'])
len(dmpg)
# Out:
# 231

# %%
dmpg.groupby('drv').agg(mean_hwy = ('hwy', 'mean'))
# Out:
#      mean_hwy
# drv
# 4       19.17
# f       27.73
# r       21.00

# %% [markdown]
# #7장 종료
